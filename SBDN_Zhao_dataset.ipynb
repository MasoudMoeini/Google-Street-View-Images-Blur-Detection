# %% [markdown]
# <a href="https://colab.research.google.com/github/MasoudMoeini/Google-Street-View-Images-Blur-Detection/blob/main/SBDN_Zhao_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import glob
import os
import numpy as np

# %%
from numpy import *
images_folder= "train/dataset/train_data/1204source/*.bmp"
labels_folder = "train/dataset/train_data/1204gt/"
def data_preprocessing(images_folder,labels_folder):
  total_img = []
  label = []
  files = glob.glob (images_folder)
  for myFile in files:
      image_name=os.path.split(myFile)[1]
      img = Image.open(myFile)
      new_img = img.resize((224, 224))
      image = array(new_img)
      new_label=Image.open(labels_folder+image_name)
      new_label = new_label.resize((224, 224))
      label_image = array(new_label)
      label.append (label_image)
      total_img.append (image)
  total_img = np.array(total_img)
  label = np.array(label)
  label= np.reshape(label,[label.shape[0],label.shape[1],label.shape[2]])
  total_img= np.reshape(total_img,[total_img.shape[0],total_img.shape[1],total_img.shape[2],total_img.shape[3]])
  return label,total_img

# %%
labels,images=data_preprocessing(images_folder,labels_folder)

# %%
labels.shape
# Out:
# (1204, 224, 224)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(40, 15))
columns = 8
rows = 3
for i in range(0, columns*rows):
    fig.add_subplot(rows, columns,i+1)
    plt.imshow(images[i],cmap='binary')
    plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(40, 15))
columns = 8
rows = 3
for i in range(0, columns*rows):
    fig.add_subplot(rows, columns,i+1)
    plt.imshow(labels[i],cmap='binary')
    plt.axis("off")
plt.show()

# %%
images.shape
# Out:
# (1204, 224, 224, 3)

# %%
labels.shape
# Out:
# (1204, 224, 224)

# %%
import cv2
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential, Model,load_model
from keras.optimizers import gradient_descent_v2 
from google.colab.patches import cv2_imshow
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
from keras import regularizers

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def decoder_network(X):
    #x_input = layers.Input(shape=(147))
    #x = keras.layers.Reshape([7,7,3])(dX)
    x = layers.Conv2DTranspose(2048, (3, 3), strides=2, activation="relu", padding="same")(X)
    x = layers.Conv2DTranspose(512, (3, 3), strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(128, (3, 3), strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(3, (3, 3), strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(3, (3, 3), strides=1, activation="relu",kernel_regularizer=regularizers.L2(l2=0.0005),
      bias_regularizer=regularizers.L2(l2=0.005), padding="same")(x)
    x = layers.Conv2DTranspose(3, (3, 3), strides=1, activation="sigmoid",kernel_regularizer=regularizers.L2(l2=0.0005),
      bias_regularizer=regularizers.L2(l2=0.005), padding="same")(x)
    output = layers.Conv2DTranspose(1, (3, 3), strides=1, activation="sigmoid", padding="same",kernel_regularizer=regularizers.L2(l2=0.005),
      bias_regularizer=regularizers.L2(l2=0.0005), name="ident")(x)
    #model = Model(inputs=X, outputs=output, name='decoder_network')
    return output

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
def ResNet50():
    X_input = layers.Input(shape=(224, 224, 3))
    X = data_augmentation(X_input)
    X = layers.Rescaling(1./255)(X)
    X = ZeroPadding2D((3, 3))(X_input)
    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')
    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')
    #7*7*2048
    output1=decoder_network(X)
    #X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    #X = Flatten()(X)
    #X = Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(X)
    #X = Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(X)
    #main = Dense( 1,activation='sigmoid', name='main',kernel_initializer=glorot_uniform(seed=0))(X)
    model = Model(inputs=X_input, outputs=output1, name='ResNet50')
    return model

# %%
model= ResNet50()

# %%
class StopOnPoint(tf.keras.callbacks.Callback):
    def __init__(self, point):
        super(StopOnPoint, self).__init__()
        self.point = point
    def on_epoch_end(self, epoch, logs=None): 
        accuracy = logs["accuracy"]
        if accuracy >= self.point:
            self.model.stop_training = True
callbacks = [StopOnPoint(0.99)]

# %%
loss1=tf.keras.losses.MeanSquaredError()
#loss2=tf.keras.losses.BinaryCrossentropy()
model.compile(keras.optimizers.Adam(learning_rate=1e-3),loss = [loss1],metrics=["accuracy"])

# %%
x_train = images.astype(np.float32)/ 255.0
y_train=labels.astype(np.float32)/ 255.0
y_train=(y_train)

# %%
history = model.fit(x_train,y_train, epochs=120,batch_size=25, validation_split=0.0,shuffle=True,callbacks=[callbacks])
model.save('sbdn-zhao-model.h5')
# Out:
# Epoch 1/120
#  6/49 [==>...........................] - ETA: 25s - loss: 0.2662 - accuracy: 0.6806
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2767s vs `on_train_batch_end` time: 0.3106s). Check your callbacks.
# 49/49 [==============================] - 29s 594ms/step - loss: 0.2658 - accuracy: 0.6756
# Epoch 2/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.2340 - accuracy: 0.6754
# Epoch 3/120
# 49/49 [==============================] - 28s 577ms/step - loss: 0.2241 - accuracy: 0.6752
# Epoch 4/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.2121 - accuracy: 0.6755
# Epoch 5/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1980 - accuracy: 0.6756
# Epoch 6/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1916 - accuracy: 0.6756
# Epoch 7/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1822 - accuracy: 0.6757
# Epoch 8/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1730 - accuracy: 0.6886
# Epoch 9/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1649 - accuracy: 0.7311
# Epoch 10/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1605 - accuracy: 0.7683
# Epoch 11/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1519 - accuracy: 0.7876
# Epoch 12/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1420 - accuracy: 0.8006
# Epoch 13/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1366 - accuracy: 0.8084
# Epoch 14/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1304 - accuracy: 0.8174
# Epoch 15/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1258 - accuracy: 0.8250
# Epoch 16/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1210 - accuracy: 0.8320
# Epoch 17/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1166 - accuracy: 0.8388
# Epoch 18/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1133 - accuracy: 0.8434
# Epoch 19/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1095 - accuracy: 0.8497
# Epoch 20/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1100 - accuracy: 0.8482
# Epoch 21/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.1082 - accuracy: 0.8497
# Epoch 22/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.1043 - accuracy: 0.8566
# Epoch 23/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0994 - accuracy: 0.8637
# Epoch 24/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0965 - accuracy: 0.8695
# Epoch 25/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0924 - accuracy: 0.8747
# Epoch 26/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0944 - accuracy: 0.8714
# Epoch 27/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0911 - accuracy: 0.8767
# Epoch 28/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0843 - accuracy: 0.8869
# Epoch 29/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0868 - accuracy: 0.8824
# Epoch 30/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0804 - accuracy: 0.8912
# Epoch 31/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0760 - accuracy: 0.8973
# Epoch 32/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0760 - accuracy: 0.8970
# Epoch 33/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0703 - accuracy: 0.9049
# Epoch 34/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0711 - accuracy: 0.9033
# Epoch 35/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0680 - accuracy: 0.9080
# Epoch 36/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0662 - accuracy: 0.9098
# Epoch 37/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0597 - accuracy: 0.9186
# Epoch 38/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0580 - accuracy: 0.9206
# Epoch 39/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0577 - accuracy: 0.9211
# Epoch 40/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0570 - accuracy: 0.9218
# Epoch 41/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0524 - accuracy: 0.9281
# Epoch 42/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0501 - accuracy: 0.9313
# Epoch 43/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0487 - accuracy: 0.9332
# Epoch 44/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0497 - accuracy: 0.9319
# Epoch 45/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0591 - accuracy: 0.9183
# Epoch 46/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0464 - accuracy: 0.9364
# Epoch 47/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0513 - accuracy: 0.9293
# Epoch 48/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0447 - accuracy: 0.9386
# Epoch 49/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0458 - accuracy: 0.9371
# Epoch 50/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0401 - accuracy: 0.9450
# Epoch 51/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0377 - accuracy: 0.9484
# Epoch 52/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0382 - accuracy: 0.9475
# Epoch 53/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0391 - accuracy: 0.9462
# Epoch 54/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0378 - accuracy: 0.9479
# Epoch 55/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0346 - accuracy: 0.9523
# Epoch 56/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0326 - accuracy: 0.9550
# Epoch 57/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0304 - accuracy: 0.9580
# Epoch 58/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0329 - accuracy: 0.9544
# Epoch 59/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0404 - accuracy: 0.9441
# Epoch 60/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0328 - accuracy: 0.9545
# Epoch 61/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0287 - accuracy: 0.9601
# Epoch 62/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0263 - accuracy: 0.9632
# Epoch 63/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0283 - accuracy: 0.9606
# Epoch 64/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0257 - accuracy: 0.9640
# Epoch 65/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0252 - accuracy: 0.9646
# Epoch 66/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0234 - accuracy: 0.9668
# Epoch 67/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0226 - accuracy: 0.9678
# Epoch 68/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0221 - accuracy: 0.9684
# Epoch 69/120
# 49/49 [==============================] - 28s 582ms/step - loss: 0.0218 - accuracy: 0.9688
# Epoch 70/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0207 - accuracy: 0.9701
# Epoch 71/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0199 - accuracy: 0.9711
# Epoch 72/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0192 - accuracy: 0.9719
# Epoch 73/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0318 - accuracy: 0.9556
# Epoch 74/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0366 - accuracy: 0.9489
# Epoch 75/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0246 - accuracy: 0.9649
# Epoch 76/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0244 - accuracy: 0.9652
# Epoch 77/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0209 - accuracy: 0.9697
# Epoch 78/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0219 - accuracy: 0.9683
# Epoch 79/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0222 - accuracy: 0.9680
# Epoch 80/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0197 - accuracy: 0.9711
# Epoch 81/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0182 - accuracy: 0.9729
# Epoch 82/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0169 - accuracy: 0.9744
# Epoch 83/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0173 - accuracy: 0.9739
# Epoch 84/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0161 - accuracy: 0.9752
# Epoch 85/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0161 - accuracy: 0.9752
# Epoch 86/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0154 - accuracy: 0.9759
# Epoch 87/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0154 - accuracy: 0.9759
# Epoch 88/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0148 - accuracy: 0.9765
# Epoch 89/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0145 - accuracy: 0.9768
# Epoch 90/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0143 - accuracy: 0.9769
# Epoch 91/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0155 - accuracy: 0.9757
# Epoch 92/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0145 - accuracy: 0.9768
# Epoch 93/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0142 - accuracy: 0.9770
# Epoch 94/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0140 - accuracy: 0.9772
# Epoch 95/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0137 - accuracy: 0.9775
# Epoch 96/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0135 - accuracy: 0.9776
# Epoch 97/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0136 - accuracy: 0.9775
# Epoch 98/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0296 - accuracy: 0.9581
# Epoch 99/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0286 - accuracy: 0.9591
# Epoch 100/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0191 - accuracy: 0.9714
# Epoch 101/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0154 - accuracy: 0.9758
# Epoch 102/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0142 - accuracy: 0.9770
# Epoch 103/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0136 - accuracy: 0.9776
# Epoch 104/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0134 - accuracy: 0.9777
# Epoch 105/120
# 49/49 [==============================] - 29s 582ms/step - loss: 0.0139 - accuracy: 0.9772
# Epoch 106/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0133 - accuracy: 0.9777
# Epoch 107/120
# 49/49 [==============================] - 28s 581ms/step - loss: 0.0295 - accuracy: 0.9581
# Epoch 108/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0180 - accuracy: 0.9726
# Epoch 109/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0149 - accuracy: 0.9762
# Epoch 110/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0136 - accuracy: 0.9775
# Epoch 111/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0138 - accuracy: 0.9772
# Epoch 112/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0183 - accuracy: 0.9719
# Epoch 113/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0147 - accuracy: 0.9763
# Epoch 114/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0132 - accuracy: 0.9778
# Epoch 115/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0127 - accuracy: 0.9782
# Epoch 116/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0128 - accuracy: 0.9781
# Epoch 117/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0125 - accuracy: 0.9784
# Epoch 118/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0134 - accuracy: 0.9774
# Epoch 119/120
# 49/49 [==============================] - 28s 580ms/step - loss: 0.0190 - accuracy: 0.9710
# Epoch 120/120
# 49/49 [==============================] - 28s 579ms/step - loss: 0.0299 - accuracy: 0.9574

# %%
history_dict = history.history
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
import pandas as pd
hist_df = pd.DataFrame(history.history)
hist_csv_file = 'sbdn-zaho-history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
#plt.plot(history.history['val_accuracy'])
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","loss"])
plt.show()

# %% [markdown]
# ## Evaluation Shi et al (CUHK)

# %%
images_folder= "train/dataset/test_data/CUHK/xu100-source/*.bmp"
labels_folder = "train/dataset/test_data/CUHK/xu100-gt/"
def data_preprocessing(images_folder,labels_folder):
  total_img = []
  label = []
  files = glob.glob (images_folder)
  for myFile in files:
      image_name=os.path.split(myFile)[1]
      img = Image.open(myFile)
      new_img = img.resize( (224, 224))
      image = array(new_img)
      new_label=Image.open(labels_folder+image_name)
      new_label = new_label.resize((224, 224))
      label_image = array(new_label)
      label.append (label_image)
      total_img.append (image)
  total_img = np.array(total_img)
  label = np.array(label)
  label= np.reshape(label,[label.shape[0],label.shape[1],label.shape[2]])
  total_img= np.reshape(total_img,[total_img.shape[0],total_img.shape[1],total_img.shape[2],total_img.shape[3]])
  return label,total_img

# %%
shi_labels,shi_images=data_preprocessing(images_folder,labels_folder)

# %%
shi_labels.shape
# Out:
# (100, 224, 224)

# %%
shi_images.shape
# Out:
# (100, 224, 224, 3)

# %%
from keras.models import load_model
images = shi_images
model = load_model("sbdn-zhao-model.h5")
predictions=[]
for i in range(images.shape[0]):
  img = images[i]
  img = img.astype(np.float32)/ 255.0
  img = np.expand_dims(img, -1)
  img = np.expand_dims(img, 0)
  pred = model.predict(img)
  predictions.append(pred)

# %%
ground_truth_total=shi_labels/255.0
ground_truth_total=np.where(ground_truth_total>0.5,1.0,0.0)

# %%
def get_mae(true_label, y_pred_label):
  absolute_error=[]
  for i in range(0,len(true_label)):
    #true_label = eval_labels[i]/255.0
    pp=np.where(((y_pred_label[i])[0])>0.5,1.0,0.0)
    y_pred=reshape(pp,[224,224])
    y_true=true_label[i]
    mae = tf.keras.losses.MeanAbsoluteError()
    m = mae(y_true, y_pred).numpy()
    absolute_error.append(m)
  return mean(absolute_error)
mean_absolute_error= get_mae(ground_truth_total,predictions)
print('Mean Absolute Error for Evaluation set: ',mean_absolute_error)
# Out:
# Mean Absolute Error for Evaluation set:  0.1004346699617347

# %%
from sklearn.metrics import precision_score,recall_score
threshoulds=[0.3,0.4,0.5,0.6,0.7]
beta2=0.2
def recall_precison(y_true,y_pred):
  OIS_F=[]
  Fb=[]
  for i in range(0,len(y_pred)):
    OIS_F_thr=[]
    fb_thr=[]
    for thr in threshoulds:
      pr=np.where(((y_pred[i])[0])>thr,1.0,0.0)
      pr=reshape(pr,[224,224])
      pred_precision_score=precision_score(y_true[i],pr, average='weighted')
      pred_recall_score=recall_score(y_true[i],pr, average='weighted')
      OIS=2*pred_precision_score*pred_recall_score/(pred_precision_score+pred_recall_score)
      fb=(1+beta2)*pred_precision_score*pred_recall_score/(beta2 * pred_precision_score+pred_recall_score)
      fb_thr.append(fb)
      OIS_F_thr.append(OIS)
    Fb.append(fb_thr)
    OIS_F.append(OIS_F_thr)
  return OIS_F,Fb

# %%
OIS_array,Fb_array=recall_precison(ground_truth_total,predictions)

# %%
def Fb_score(Fb_array):
  best_Fb=[]
  for results in Fb_array:
    f_score=max(results)
    best_Fb.append(f_score)
  return np.nanmean(best_Fb)
mean_Fb_score= Fb_score(Fb_array)
print('Fb score: ',mean_Fb_score)
# Out:
# Fb score:  0.8471578475677687

# %%
def OIS_F_score(OIS_array):
  best_OIS_F=[]
  index_max=[]
  for results in OIS_array:
    f_score=max(results)
    best_OIS_F.append(f_score)
    index = results.index(f_score)
    index_max.append(index)
  return best_OIS_F,index_max
OIS_f1,indexes=OIS_F_score(OIS_array)
print('Average Optimal Image Scale F score: ',np.nanmean(OIS_f1))
# Out:
# Average Optimal Image Scale F score:  0.8609413609673244

# %% [markdown]
# ## Evaluation DUT dataset

# %%
images_folder= "train/dataset/test_data/DUT/dut500-source/*.bmp"
labels_folder = "train/dataset/test_data/DUT/dut500-gt/"
def data_preprocessing(images_folder,labels_folder):
  total_img = []
  label = []
  files = glob.glob (images_folder)
  for myFile in files:
      image_name=os.path.split(myFile)[1]
      img = Image.open(myFile)
      new_img = img.resize( (224, 224))
      image = array(new_img)
      new_label=Image.open(labels_folder+image_name)
      new_label = new_label.resize((224, 224))
      label_image = array(new_label)
      label.append (label_image)
      total_img.append (image)
  total_img = np.array(total_img)
  label = np.array(label)
  label= np.reshape(label,[label.shape[0],label.shape[1],label.shape[2]])
  total_img= np.reshape(total_img,[total_img.shape[0],total_img.shape[1],total_img.shape[2],total_img.shape[3]])
  return label,total_img

# %%
dut_labels,dut_images=data_preprocessing(images_folder,labels_folder)

# %%
dut_labels.shape
# Out:
# (500, 224, 224)

# %%
dut_images.shape
# Out:
# (500, 224, 224, 3)

# %%
images = dut_images
model = load_model("sbdn-zhao-model.h5")
predictions=[]
for i in range(images.shape[0]):
  img = images[i]
  img = img.astype(np.float32)/ 255.0
  img = np.expand_dims(img, -1)
  img = np.expand_dims(img, 0)
  pred = model.predict(img)
  predictions.append(pred)

# %%
ground_truth_total=dut_labels/255.0
ground_truth_total=np.where(ground_truth_total>0.5,1.0,0.0)

# %%
def get_mae(true_label, y_pred_label):
  absolute_error=[]
  for i in range(0,len(true_label)):
    #true_label = eval_labels[i]/255.0
    pp=np.where(((y_pred_label[i])[0])>0.5,1.0,0.0)
    y_pred=reshape(pp,[224,224])
    y_true=true_label[i]
    mae = tf.keras.losses.MeanAbsoluteError()
    m = mae(y_true, y_pred).numpy()
    absolute_error.append(m)
  return mean(absolute_error)
mean_absolute_error= get_mae(ground_truth_total,predictions)
print('Mean Absolute Error for Evaluation set: ',mean_absolute_error)
# Out:
# Mean Absolute Error for Evaluation set:  0.1199820631377551

# %%
from sklearn.metrics import precision_score,recall_score
threshoulds=[0.3,0.4,0.5,0.6,0.7]
beta2=0.2
def recall_precison(y_true,y_pred):
  OIS_F=[]
  Fb=[]
  for i in range(0,len(y_pred)):
    OIS_F_thr=[]
    fb_thr=[]
    for thr in threshoulds:
      pr=np.where(((y_pred[i])[0])>thr,1.0,0.0)
      pr=reshape(pr,[224,224])
      pred_precision_score=precision_score(y_true[i],pr, average='weighted')
      pred_recall_score=recall_score(y_true[i],pr, average='weighted')
      OIS=2*pred_precision_score*pred_recall_score/(pred_precision_score+pred_recall_score)
      fb=(1+beta2)*pred_precision_score*pred_recall_score/(beta2 * pred_precision_score+pred_recall_score)
      fb_thr.append(fb)
      OIS_F_thr.append(OIS)
    Fb.append(fb_thr)
    OIS_F.append(OIS_F_thr)
  return OIS_F,Fb

# %%
OIS_array,Fb_array=recall_precison(ground_truth_total,predictions)

# %%
def Fb_score(Fb_array):
  best_Fb=[]
  for results in Fb_array:
    f_score=max(results)
    best_Fb.append(f_score)
  return np.nanmean(best_Fb)
mean_Fb_score= Fb_score(Fb_array)
print('Fb score: ',mean_Fb_score)
# Out:
# Fb score:  0.8304771159090248

# %%
def OIS_F_score(OIS_array):
  best_OIS_F=[]
  index_max=[]
  for results in OIS_array:
    f_score=max(results)
    best_OIS_F.append(f_score)
    index = results.index(f_score)
    index_max.append(index)
  return best_OIS_F,index_max
OIS_f1,indexes=OIS_F_score(OIS_array)
print('Average Optimal Image Scale F score: ',np.nanmean(OIS_f1))
# Out:
# Average Optimal Image Scale F score:  0.8315539755153603
